# %% [markdown]
# ## Cek GPU

# %%
# !nvidia-smi
# Out:
# Thu Jan  1 16:33:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## Install Library

# %%
# %pip install ultralytics gdown
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.245-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.245-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 35.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.245 ultralytics-thop-2.0.18

# %% [markdown]
# ## Matikan tracking Ultralytics

# %%
import ultralytics
from ultralytics import settings
print(f"Versi Ultralytics: {ultralytics.__version__}")

# Disable analytics and crash reporting
settings.update({"sync": False})

print(f"Tracking status (sync): {settings['sync']}") # matikan tracking
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Versi Ultralytics: 8.3.245
# Tracking status (sync): False

# %% [markdown]
# ## Download Dataset dari Google Drive Link

# %%
# Hapus folder datasets (berisi gambar)
# !rm -rf datasets

# Hapus folder project_batik (berisi hasil training sebelumnya)
# !rm -rf project_batik

# Hapus file zip jika ingin bersih total
# !rm -rf batik_dataset.zip

print("Folder berhasil dihapus.")
# Out:
# Folder berhasil dihapus.

# %%
import gdown
import os

file_id = '...'

output_file = 'batik_dataset.zip'
url = f'https://drive.google.com/uc?id={file_id}'

if not os.path.exists(output_file):
    print("Sedang mendownload dataset...")
    gdown.download(url, output_file, quiet=False)
else:
    print("File zip sudah ada.")

# Unzip dataset
# !unzip -q batik_dataset.zip -d datasets/
print("Dataset berhasil di-unzip ke folder 'datasets/'")
# Out:
# Sedang mendownload dataset...
# Downloading...
# From (original): https://drive.google.com/uc?id=1WHipH1I6FOCWWMBsWTvwB2RSiQ8SPez4
# From (redirected): https://drive.google.com/uc?id=1WHipH1I6FOCWWMBsWTvwB2RSiQ8SPez4&confirm=t&uuid=f76cf89c-af9b-4882-b24d-639c3a5e1d01
# To: /content/batik_dataset.zip
# 100%|██████████| 185M/185M [00:01<00:00, 149MB/s]
# Dataset berhasil di-unzip ke folder 'datasets/'

# %% [markdown]
# ## Cari file Yaml

# %%
import yaml
import os

# Cari file data.yaml
yaml_path = None
for root, dirs, files in os.walk("datasets"):
    if "data.yaml" in files:
        yaml_path = os.path.join(root, "data.yaml")
        break

if yaml_path:
    print(f"File konfigurasi ditemukan di: {yaml_path}")

    # Baca dan perbaiki path
    with open(yaml_path, 'r') as f:
        data = yaml.safe_load(f)

    # Hapus path hardcode, ganti dengan path relatif Colab
    data['path'] = os.path.abspath(os.path.dirname(yaml_path))
    # Pastikan train/val menunjuk ke folder yang benar relative terhadap 'path'
    data['train'] = 'train/images'
    data['val'] = 'valid/images' # Roboflow biasanya menamakan folder ini 'valid'
    data['test'] = 'test/images' if 'test' in data else None

    # Simpan ulang
    with open(yaml_path, 'w') as f:
        yaml.dump(data, f)
    print("data.yaml berhasil diperbaiki untuk Colab.")
else:
    print("ERROR: data.yaml tidak ditemukan! Cek struktur folder datasets Anda.")
# Out:
# File konfigurasi ditemukan di: datasets/data.yaml
# data.yaml berhasil diperbaiki untuk Colab.

# %% [markdown]
# ## Pastikan semua gambar tidak ada anotasi rectangle

# %%
import os

def find_rectangle_labels(dataset_path):
    print(f"🔍 Scanning {dataset_path} for incompatible labels...")
    bad_files = []

    # Walk through all folders and subfolders
    for root, dirs, files in os.walk(dataset_path):
        for file in files:
            if file.endswith(".txt") and file != "classes.txt":
                filepath = os.path.join(root, file)

                try:
                    with open(filepath, 'r') as f:
                        lines = f.readlines()

                    for i, line in enumerate(lines):
                        parts = line.strip().split()

                        # Ignore empty lines
                        if not parts:
                            continue

                        # CRITICAL CHECK:
                        # Detection labels have exactly 5 items (class, x, y, w, h).
                        # Segmentation labels must have > 5 items (class + at least 3 points).
                        if len(parts) == 5:
                            print(f"⚠️  PROBLEM FOUND: {filepath}")
                            print(f"    Line {i+1}: {line.strip()}")
                            bad_files.append(filepath)
                            break # Found a bad line, no need to check the rest of this file

                except Exception as e:
                    print(f"Error reading {filepath}: {e}")

    print("-" * 30)
    if bad_files:
        print(f"❌ Found {len(bad_files)} files with rectangle annotations.")
    else:
        print("✅ No rectangle annotations found. All labels appear to be polygons.")

    return bad_files

# --- UPDATE THIS PATH ---
# Example: "/content/datasets/coco8-seg" or "C:/projects/data"
dataset_path = "/content/datasets/"

# Run the function
bad_files_list = find_rectangle_labels(dataset_path)
# Out:
# 🔍 Scanning /content/datasets/ for incompatible labels...
# ⚠️  PROBLEM FOUND: /content/datasets/README.dataset.txt
#     Line 4: Provided by a Roboflow user
# ⚠️  PROBLEM FOUND: /content/datasets/README.roboflow.txt
#     Line 9: * collect & organize images
# ------------------------------
# ❌ Found 2 files with rectangle annotations.

# %% [markdown]
# ## Training

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

# --- MULAI TRAINING ---
results = model.train(
    data=yaml_path,     # Path otomatis dari blok sebelumnya
    epochs=50,          # 50 epoch cukup untuk percobaan awal
    imgsz=640,          # Ukuran standar
    batch=16,           # Aman untuk GPU T4 Colab
    patience=10,        # Stop kalau tidak ada peningkatan dalam 10 epoch (hemat waktu)
    project='project_batik', # Nama folder output
    name='hasil_training',
    exist_ok=True,      # Timpa folder jika sudah ada
    verbose=True
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 313.1MB/s 0.0s
# Ultralytics 8.3.245 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=datasets/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=hasil_training, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=project_batik, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/project_batik/hasil_training, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 111.7MB/s 0.0s
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431062  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,230 parameters, 2,590,214 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1560.4±591.1 MB/s, size: 47.9 KB)
# train: Scanning /content/datasets/train/labels... 2747 images, 441 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2747/2747 2.2Kit/s 1.2s
# train: /content/datasets/train/images/71_jpg.rf.539187ad504cd3f11f8619f2783413e9.jpg: 1 duplicate labels removed
# train: /content/datasets/train/images/71_jpg.rf.8eb977312d656cc3056d5c504c48d8cd.jpg: 1 duplicate labels removed
# train: /content/datasets/train/images/71_jpg.rf.d4fcf5a8c4860dcb223825f9273bd71b.jpg: 1 duplicate labels removed
# train: New cache created: /content/datasets/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 839.2±508.3 MB/s, size: 73.9 KB)
# val: Scanning /content/datasets/valid/labels... 263 images, 38 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 263/263 1.3Kit/s 0.2s
# val: /content/datasets/valid/images/45_jpg.rf.b10293bf738e8359d544546c741564f9.jpg: 2 duplicate labels removed
# val: New cache created: /content/datasets/valid/labels.cache
# Plotting labels to /content/project_batik/hasil_training/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/project_batik/hasil_training
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.21G     0.7599      2.102      1.217         26        640: 100% ━━━━━━━━━━━━ 172/172 2.5it/s 1:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 1.1it/s 8.5s
#                    all        263        313      0.539      0.594      0.582      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.74G     0.9038      1.566      1.305         37        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.1it/s 2.2s
#                    all        263        313      0.612      0.613      0.574      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.76G     0.9461      1.397      1.339         26        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.7it/s 1.9s
#                    all        263        313      0.683      0.569      0.605      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.77G     0.9174      1.286      1.319         29        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 46.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s
#                    all        263        313      0.689      0.352      0.452      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.79G     0.8875       1.17       1.29         29        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.8it/s 2.4s
#                    all        263        313      0.724      0.573       0.67      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50       2.8G      0.841      1.141      1.266         29        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 47.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.3it/s 2.7s
#                    all        263        313      0.658      0.621      0.639      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.82G     0.8308      1.109      1.255         26        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 47.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.5it/s 2.6s
#                    all        263        313       0.63      0.618      0.646      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.83G     0.7933      1.036      1.233         26        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.9it/s 2.3s
#                    all        263        313      0.798      0.633       0.72        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      2.85G     0.7725      1.016      1.215         38        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.5it/s 2.6s
#                    all        263        313      0.751      0.557      0.635      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      2.86G     0.7526     0.9886      1.204         38        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 46.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.1it/s 2.9s
#                    all        263        313      0.761      0.649      0.718      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      2.88G     0.7235     0.9181      1.192         28        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.4it/s 2.6s
#                    all        263        313      0.814      0.694       0.75      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      2.89G     0.7331     0.9393      1.194         30        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 47.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.2it/s 2.8s
#                    all        263        313      0.788      0.582      0.707      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      2.91G     0.7073      0.915      1.171         24        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 46.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.3it/s 2.7s
#                    all        263        313      0.736      0.639      0.712      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      2.92G     0.6838     0.8854      1.155         30        640: 100% ━━━━━━━━━━━━ 172/172 3.8it/s 45.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.5it/s 2.5s
#                    all        263        313      0.784      0.706      0.752      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      2.94G     0.6733     0.8428       1.15         32        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 46.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.1it/s 2.2s
#                    all        263        313      0.837      0.607      0.736      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      2.95G     0.6788     0.8416      1.155         29        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 46.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.0it/s 2.2s
#                    all        263        313      0.836      0.678       0.77      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      2.96G     0.6744     0.8387      1.143         33        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.8it/s 1.9s
#                    all        263        313      0.726       0.69       0.72      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      2.98G     0.6357     0.7795      1.123         24        640: 100% ━━━━━━━━━━━━ 172/172 3.5it/s 48.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.2it/s 2.2s
#                    all        263        313        0.8      0.659      0.747      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         3G     0.6354     0.7623      1.119         23        640: 100% ━━━━━━━━━━━━ 172/172 3.5it/s 48.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.0it/s 2.3s
#                    all        263        313      0.771      0.723      0.782      0.614
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      3.01G     0.6323     0.7425      1.119         27        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.2it/s 2.1s
#                    all        263        313      0.854      0.746      0.813      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      3.03G     0.6169     0.7427      1.108         28        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.9it/s 2.3s
#                    all        263        313      0.794      0.654      0.731      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      3.04G     0.6125     0.7376      1.104         29        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.6it/s 2.5s
#                    all        263        313       0.82      0.703      0.787      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      3.05G     0.6043     0.7148      1.099         34        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 47.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 2.9it/s 3.1s
#                    all        263        313      0.804      0.709      0.773      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      3.07G     0.6016       0.68      1.095         26        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 46.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 2.8it/s 3.2s
#                    all        263        313      0.855      0.706      0.797      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      3.08G     0.5864     0.6609      1.082         23        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 2.9it/s 3.1s
#                    all        263        313      0.824      0.718        0.8      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50       3.1G     0.5829     0.6544      1.083         32        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 47.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s
#                    all        263        313      0.857      0.696      0.797      0.636
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      3.11G     0.5647     0.6444      1.065         26        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s
#                    all        263        313      0.729      0.746      0.772      0.608
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      3.13G     0.5658     0.6565      1.075         22        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.5it/s 2.6s
#                    all        263        313      0.782      0.748      0.794      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      3.14G     0.5494     0.6161      1.063         26        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.2it/s 2.9s
#                    all        263        313      0.808      0.706      0.782       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      3.16G      0.567      0.609      1.069         42        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.6it/s 2.5s
#                    all        263        313      0.851      0.695      0.767        0.6
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      3.17G     0.5459     0.6013      1.064         21        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.3it/s 2.1s
#                    all        263        313      0.847      0.711      0.793       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      3.19G     0.5353     0.5892      1.048         30        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.1it/s 2.2s
#                    all        263        313      0.817      0.751      0.806      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50       3.2G     0.5343     0.5727       1.05         38        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.0it/s 2.3s
#                    all        263        313      0.817      0.741      0.802      0.651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      3.22G     0.5229     0.5504      1.041         25        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.8it/s 2.4s
#                    all        263        313      0.819      0.756       0.82      0.652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      3.23G     0.5291     0.5584      1.046         31        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.2it/s 2.1s
#                    all        263        313      0.825      0.764      0.831      0.683
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      3.25G     0.5179     0.5445      1.042         28        640: 100% ━━━━━━━━━━━━ 172/172 3.5it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.0it/s 2.3s
#                    all        263        313      0.826      0.754      0.816      0.682
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      3.26G     0.5037     0.5277      1.032         31        640: 100% ━━━━━━━━━━━━ 172/172 3.5it/s 48.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.8it/s 2.4s
#                    all        263        313      0.848      0.743      0.815      0.677
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      3.28G     0.4929     0.5058      1.024         38        640: 100% ━━━━━━━━━━━━ 172/172 3.5it/s 48.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.8it/s 2.3s
#                    all        263        313      0.813      0.757      0.806      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      3.29G      0.492     0.5049      1.029         31        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 48.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.3it/s 2.1s
#                    all        263        313      0.854      0.732      0.838      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      3.31G      0.494     0.5083      1.026         27        640: 100% ━━━━━━━━━━━━ 172/172 3.6it/s 47.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.9it/s 2.3s
#                    all        263        313      0.809      0.793      0.826      0.684
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      3.32G      0.414     0.4384       1.03          8        640: 100% ━━━━━━━━━━━━ 172/172 3.7it/s 46.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.6it/s 2.0s
#                    all        263        313      0.816      0.738      0.808       0.67
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      3.34G     0.3876     0.3871      1.001          8        640: 100% ━━━━━━━━━━━━ 172/172 3.9it/s 44.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.5it/s 2.0s
#                    all        263        313      0.772      0.757      0.795      0.666
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      3.35G     0.3968     0.3768      1.013         12        640: 100% ━━━━━━━━━━━━ 172/172 3.9it/s 43.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.0it/s 1.8s
#                    all        263        313      0.868      0.761       0.83      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      3.37G     0.3776     0.3619     0.9869         13        640: 100% ━━━━━━━━━━━━ 172/172 3.8it/s 45.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.0it/s 1.8s
#                    all        263        313      0.863      0.748      0.836      0.704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      3.38G     0.3621     0.3304      0.983         12        640: 100% ━━━━━━━━━━━━ 172/172 3.9it/s 44.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.6it/s 2.5s
#                    all        263        313      0.878      0.736      0.822      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      3.39G     0.3595     0.3184     0.9798         11        640: 100% ━━━━━━━━━━━━ 172/172 3.9it/s 43.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.1it/s 1.8s
#                    all        263        313      0.834      0.756      0.815      0.688
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      3.41G     0.3508     0.3245     0.9684         12        640: 100% ━━━━━━━━━━━━ 172/172 3.8it/s 44.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 4.9it/s 1.8s
#                    all        263        313      0.841       0.76      0.816      0.693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      3.42G     0.3372     0.3046      0.955         12        640: 100% ━━━━━━━━━━━━ 172/172 3.9it/s 44.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.5it/s 2.6s
#                    all        263        313      0.832      0.772      0.818       0.69
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      3.44G     0.3395     0.2984      0.962         12        640: 100% ━━━━━━━━━━━━ 172/172 3.9it/s 44.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.0it/s 1.8s
#                    all        263        313      0.847      0.759       0.82      0.691
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      3.46G     0.3275     0.2793     0.9546         13        640: 100% ━━━━━━━━━━━━ 172/172 3.8it/s 44.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 5.0it/s 1.8s
#                    all        263        313      0.866      0.762       0.83      0.701
#
# 50 epochs completed in 0.700 hours.
# Optimizer stripped from /content/project_batik/hasil_training/weights/last.pt, 5.5MB
# Optimizer stripped from /content/project_batik/hasil_training/weights/best.pt, 5.5MB
#
# Validating /content/project_batik/hasil_training/weights/best.pt...
# Ultralytics 8.3.245 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 2.6it/s 3.5s
#                    all        263        313      0.864      0.751      0.837      0.704
#            megamendung        111        156      0.853      0.769      0.848      0.735
#                 parang        115        157      0.874      0.732      0.825      0.673
# Speed: 0.2ms preprocess, 2.5ms inference, 0.0ms loss, 4.7ms postprocess per image
# Results saved to /content/project_batik/hasil_training

# %% [markdown]
# ## Visualisasi Hasil Training

# %%
import os
from IPython.display import Image, display

# Path output training (sesuai setting project='project_batik', name='hasil_training')
output_dir = 'project_batik/hasil_training'

# %%
print("=== 1. Grafik Performa Training (Loss & mAP) ===")
# results.png berisi ringkasan Loss, Precision, Recall, dan mAP per epoch
results_path = os.path.join(output_dir, 'results.png')
display(Image(filename=results_path, width=800))
# Out:
# === 1. Grafik Performa Training (Loss & mAP) ===

# %%
print("\n=== 2. Confusion Matrix ===")
# Melihat apakah Megamendung tertukar dengan Parang
cm_path = os.path.join(output_dir, 'confusion_matrix_normalized.png')
display(Image(filename=cm_path, width=600))
# Out:
# === 2. Confusion Matrix ===

# %%
print("\n=== 3. Kurva Box ===")
# Semakin kurva mendekati pojok kanan atas, semakin bagus
display(Image(filename=os.path.join(output_dir, 'BoxPR_curve.png'), width=600))

display(Image(filename=os.path.join(output_dir, 'BoxF1_curve.png'), width=600))
display(Image(filename=os.path.join(output_dir, 'BoxP_curve.png'), width=600))
display(Image(filename=os.path.join(output_dir, 'BoxR_curve.png'), width=600))
# Out:
# === 3. Kurva Box ===

# %%
print("\n=== 4. Contoh Hasil Prediksi pada Data Validasi ===")
# Menampilkan contoh gambar yang diprediksi model
for i in range(3):
    print(f"\n\n=== Batch {i+1} ===")
    display(Image(filename=os.path.join(output_dir, f'val_batch{i}_labels.jpg'), width=800))
    display(Image(filename=os.path.join(output_dir, f'val_batch{i}_pred.jpg'), width=800))
# Out:
# === 4. Contoh Hasil Prediksi pada Data Validasi ===
#
#
# === Batch 1 ===
# === Batch 2 ===
# === Batch 3 ===

# %% [markdown]
# ## Export ke TFlite

# %%
from ultralytics import YOLO

# 1. Load model terbaik hasil training tadi
best_model_path = 'project_batik/hasil_training/weights/best.pt'
model = YOLO(best_model_path)

print(f"Sedang mengonversi model: {best_model_path} ke tflite...")

# 2. Lakukan Export
# dynamic=False -> Kita set False agar performa lebih stabil di mobile (static input size)
success = model.export(format='tflite', dynamic=False)

print(f"Export selesai: {success}")
# Out:
# Sedang mengonversi model: project_batik/hasil_training/weights/best.pt ke tflite...
# Ultralytics 8.3.245 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'project_batik/hasil_training/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<2.0.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.71', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 20 packages in 6.40s
# Prepared 11 packages in 7.54s
# Installed 11 packages in 265ms
#  + ai-edge-litert==2.1.0
#  + backports-strenum==1.3.1
#  + colorama==0.4.6
#  + coloredlogs==15.0.1
#  + humanfriendly==10.0
#  + onnx==1.20.0
#  + onnx-graphsurgeon==0.5.8
#  + onnx2tf==1.28.8
#  + onnxruntime-gpu==1.23.2
#  + onnxslim==0.1.81
#  + sng4onnx==1.0.4
#
# requirements: AutoUpdate success ✅ 14.8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.20.0 opset 22...
# /usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/torchscript_exporter/utils.py:1447: OnnxExporterWarning: Exporting to ONNX opset version 22 is not supported. by 'torch.onnx.export()'. The highest opset version supported is 20. To use a newer opset version, consider 'torch.onnx.export(..., dynamo=True)'.
#   warnings.warn(
# ONNX: slimming with onnxslim 0.1.81...
# ONNX: export success ✅ 1.8s, saved as 'project_batik/hasil_training/weights/best.onnx' (10.2 MB)
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 40.8MB/s 0.0s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 53.8files/s 0.0s
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at 'project_batik/hasil_training/weights/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 6, 8400), dtype=tf.float32, name=None)
# Captures:
#   138950416203024: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   138950416201488: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   138950416202256: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   138950382309008: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   138950382309392: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   138950382308624: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950382309584: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   138950382309776: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950382310736: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382310352: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382312656: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   138950382313232: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   138950382309968: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   138950382306128: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   138950382311312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382310928: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382313424: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   138950382314000: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950382312272: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   138950382314384: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138950382312080: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950382314576: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138950382314192: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950382315536: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382314768: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382315920: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   138950382316880: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   138950382312848: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   138950382313616: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950382314960: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382315344: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382317072: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   138950382313808: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950382317456: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   138950382316112: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   138950382317264: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950382317648: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   138950382317840: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950382318416: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382318224: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382320336: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   138950382320528: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950382319760: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   138950382320720: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950382320912: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   138950382321104: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950382319952: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   138950382321488: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950382319376: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   138950382316304: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   138950382321296: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950382318032: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950251938256: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138950251937872: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950382318608: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950382318800: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251938640: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   138950251938832: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950251939024: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   138950251938064: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   138950251938448: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138950251939408: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   138950251939600: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138950251940176: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251939984: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251942096: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   138950251942288: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950251941520: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138950251942480: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950251942672: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138950251942864: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950251941712: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138950251943248: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950251941136: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138950251939216: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   138950251943440: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950251939792: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950251944016: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   138950251943056: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950251940368: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251940560: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251944208: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   138950251944400: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138950251943632: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   138950251944592: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950251944784: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   138950251943824: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138950251945168: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   138950251945744: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138950251945552: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   138950251946128: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138950251945360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   138950251946320: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950251946896: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   138950251951504: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950251950160: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   138950251950352: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138950251951312: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   138950251951120: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950251950544: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   138950251949968: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138950251950736: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   138950251949200: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950251950928: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251951888: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251953232: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   138950251953424: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138950251944976: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   138950251951696: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138950251952272: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251948432: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138950251952848: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   138950251952656: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138950251953040: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   138950251954000: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917278864: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917278672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917280784: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   138949917280976: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   138949917278288: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   138949917278480: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138949917279056: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917279248: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917281168: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   138949917279824: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917281552: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   138949917280208: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949917281360: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917283472: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   138949917282896: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138949917283664: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917284432: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917286736: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   138949917284624: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   138949917286160: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   138949917287120: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917285008: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917285200: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917288464: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   138949917288272: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138949917289232: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   138949917288080: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   138949917287696: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138949917290192: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   138949917287888: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138949917290384: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917291152: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917293456: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   138949917291344: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917294224: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949917292880: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917293072: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949911576656: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911577424: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949911576848: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911577232: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949917291536: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   138949911577616: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917292496: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911578192: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   138949911577808: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138949917291728: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949917291920: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   138949911578384: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   138949911578576: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138949911578000: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   138949917289040: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   138949917282128: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   138949911579152: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   138949917288848: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   138949917282320: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911579920: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   138949917288656: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   138949917283088: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138949911578960: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917286928: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917280400: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911579536: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   138949911577040: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   138949917290768: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   138949917289424: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   138949917284048: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   138949917281936: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949911580688: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911578768: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917290960: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917289808: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917284240: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917281744: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911581072: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138949911579344: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949917294032: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138949917289616: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949917284816: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138949917282704: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   138949911580304: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911579728: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917293648: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917286352: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917285776: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917282512: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911581264: TensorSpec(shape=(1, 1, 64, 2), dtype=tf.float32, name=None)
#   138949911580112: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138949917294416: TensorSpec(shape=(1, 1, 64, 2), dtype=tf.float32, name=None)
#   138949917290576: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138949917287504: TensorSpec(shape=(1, 1, 64, 2), dtype=tf.float32, name=None)
#   138949917283856: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   138949911580496: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949911581456: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   138949917290000: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917293840: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   138949917283280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   138949917287312: TensorSpec(shape=(2,), dtype=tf.float32, name=None)
#   138949911583568: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   138949911583184: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   138949911584528: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   138949911582416: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   138949911580880: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   138949911583376: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   138949911582032: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
# TensorFlow SavedModel: export success ✅ 39.4s, saved as 'project_batik/hasil_training/weights/best_saved_model' (25.6 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as 'project_batik/hasil_training/weights/best_saved_model/best_float32.tflite' (10.1 MB)
#
# Export complete (40.1s)
# Results saved to /content/project_batik/hasil_training/weights
# Predict:         yolo predict task=detect model=project_batik/hasil_training/weights/best_saved_model/best_float32.tflite imgsz=640
# Validate:        yolo val task=detect model=project_batik/hasil_training/weights/best_saved_model/best_float32.tflite imgsz=640 data=datasets/data.yaml
# Visualize:       https://netron.app
# Export selesai: project_batik/hasil_training/weights/best_saved_model/best_float32.tflite

# %%
from google.colab import files

# Download Model tflite
tflite_path = 'project_batik/hasil_training/weights/best_saved_model/best_float32.tflite'
if os.path.exists(tflite_path):
    print("Mendownload best.tflite...")
    files.download(tflite_path)
    print("Download selesai.")
else:
    print("File tflite tidak ditemukan.")
# Out:
# Mendownload best.tflite...
# Download selesai.
